# %% [markdown]
# # Deploying an AI model
# ![LifeCycle.jpeg](data:image/jpeg;base64,...)

# %%
import joblib
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn import preprocessing
import numpy as np
from keras.preprocessing.image import load_img, img_to_array, ImageDataGenerator
from keras.applications.vgg16 import preprocess_input
from keras.models import load_model
from sklearn.ensemble import RandomForestClassifier

# %% [markdown]
# ### -------------------- Machine Learning Model: Alzheimer detection ------------------
# [Kaggle link](https://www.kaggle.com/code/hyunseokc/detecting-early-alzheimer-s)
#
# Data we will use:
# Gender 0: Male, 1 Female\
# Age : integer [60,90]\
# EDUC	Years of education: integer [6,23] \
# SES	Socioeconomic Status; integer [1,5] \
# MMSE	Mini Mental State Examination [17,30] \

# %%
# Load the model
model = joblib....
# Out:
# ['alzheimer_detection.joblib']

# %%
# Make a predicition
input =  np.array([[ , , , , , ]])

prediciton = model.predict(input)
# Out:
# [[ 1. 87. 14.  2. 27.]]
# /usr/local/lib/python3.7/dist-packages/sklearn/base.py:451: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   "X does not have valid feature names, but"

# %% [markdown]
# ### -------------------- Deep learnig Model : Tumor detection ------------------

# %%
# Load the model
model = ...

# %%
#load the image, target_size = (224, 224,3)
my_image = load_img...

#preprocess the image
my_image = img_to_array(my_image)
my_image = my_image.reshape((1, my_image.shape[0], my_image.shape[1], my_image.shape[2]))
my_image = preprocess_input(my_image)

# %%
#make the prediction
prediction = model....
